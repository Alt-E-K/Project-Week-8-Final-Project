# %% [markdown]
# #Import modules
# import imdb
# import pandas as pd
# import numpy as np

# %%
#open the csv file
path =r'C:\Users\Usuario\Desktop\gits\Project-Week-8-Final-Project\Data'
movies_gross=pd.read_csv(path+'/'+'moviesgrossrev.csv', index_col='Unnamed: 0')

# %%
movies_gross
# Out:
#                                           title gross_worldwide
# 0                             Avengers: Endgame  $2,797,800,564
# 1                                        Avatar  $2,790,439,000
# 2                                       Titanic  $2,195,169,696
# 3    Star Wars: Episode VII - The Force Awakens  $2,068,223,624
# 4                        Avengers: Infinity War  $2,048,359,754
# ..                                          ...             ...
# 995                                 Unstoppable    $167,805,466
# 996                        Three Men and a Baby    $167,780,960
# 997                                  Magic Mike    $167,739,368
# 998                                   Alexander    $167,298,192
# 999                               Up in the Air    $166,842,739
#
# [1000 rows x 2 columns]

# %%
movies_gross.title[0]
# Out:
# 'Avengers: Endgame'

# %%
#initialize de imdb object
moviesDB = imdb.IMDb()

# %%
moviesDB

# %%
#to get the plot, director, country, language, genres, rating
movies = moviesDB.search_movie(movies_gross.title[0])
movie_id = movies[0].getID()
movies_info=moviesDB.get_movie(movie_id)
movies_info['plot'][0]
# Out:
# "After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe."

# %%
movie = moviesDB.get_movie('0499549')
plot = movie['plot'][0]

# %%
plot
# Out:
# 'A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.'

# %%
#loop to get the year of the movie and its id
movie_ids=[]
movie_years=[]
for i in range(len(movies_gross.title)):
    movies = moviesDB.search_movie(movies_gross.title[i])
    movie_id = movies[0].getID()
    movie_ids.append(movie_id)
    movie_year=movies[0]['year']
    movie_years.append(movie_year)

# %%
movie_years
# Out:
# [2019,
#  2005,
#  1997,
#  2015,
#  2018,
#  2019,
#  2015,
#  2012,
#  2015,
#  2019,
#  2015,
#  2011,
#  2018,
#  2017,
#  2018,
#  2013,
#  2017,
#  2018,
#  2017,
#  2013,
#  2015,
#  2016,
#  2018,
#  2003,
#  2019,
#  2019,
#  2011,
#  2012,
#  2014,
#  2012,
#  2019,
#  2019,
#  2019,
#  2010,
#  2006,
#  2016,
#  2019,
#  2011,
#  2008,
#  2017,
#  1993,
#  2016,
#  1999,
#  2010,
#  2016,
#  2012,
#  2001,
#  2010,
#  2013,
#  2019,
#  2016,
#  2003,
#  2017,
#  2007,
#  2013,
#  2014,
#  2002,
#  2007,
#  2009,
#  2004,
#  2018,
#  2005,
#  2007,
#  2001,
#  2009,
#  2015,
#  2002,
#  2017,
#  2012,
#  2016,
#  2016,
#  2017,
#  2005,
#  2013,
#  2017,
#  2015,
#  2018,
#  2017,
#  2009,
#  2010,
#  2012,
#  2002,
#  2017,
#  1996,
#  2016,
#  2007,
#  2017,
#  2018,
#  2004,
#  2019,
#  2017,
#  1982,
#  2009,
#  2008,
#  2004,
#  2013,
#  2018,
#  2016,
#  1977,
#  2014,
#  2006,
#  2019,
#  2014,
#  2004,
#  2014,
#  2010,
#  2012,
#  2016,
#  2014,
#  2005,
#  2013,
# ...

# %%
movie_ids
# Out:
# ['4154796',
#  '0417299',
#  '0120338',
#  '2488496',
#  '4154756',
#  '6105098',
#  '0369610',
#  '0848228',
#  '2820852',
#  '4520988',
#  '2395427',
#  '1201607',
#  '1825683',
#  '2527336',
#  '4881806',
#  '2294629',
#  '2771200',
#  '3606756',
#  '4630562',
#  '1300854',
#  '2293640',
#  '3498820',
#  '1477834',
#  '0167260',
#  '6320628',
#  '4154664',
#  '1399103',
#  '1074638',
#  '2109248',
#  '1345836',
#  '7286456',
#  '2527338',
#  '1979376',
#  '0435761',
#  '0383574',
#  '3748528',
#  '6139732',
#  '1298650',
#  '0468569',
#  '3469046',
#  '0107290',
#  '2277860',
#  '0120915',
#  '1014759',
#  '2948356',
#  '0903624',
#  '0241527',
#  '0926084',
#  '1690953',
#  '6105098',
#  '3040964',
#  '0266543',
#  '2283362',
#  '0449088',
#  '1170358',
#  '2310332',
#  '0167261',
#  '0373889',
#  '0417741',
#  '0298148',
#  '1727824',
#  '0330373',
#  '0413300',
#  '0120737',
#  '1080016',
#  '2379713',
#  '0295297',
#  '2250912',
#  '1667889',
#  '2709768',
#  '2975590',
# ...

# %%
movies_gross['movie_id']=movie_ids

# %%
movies_gross['year']=movie_years

# %%
#new csv file with the years and the ids
movies_gross.to_csv(path+'/'+'movies_id_year.csv')

# %%
movies_gross
# Out:
#                                           title gross_worldwide movie_id  year
# 0                             Avengers: Endgame  $2,797,800,564  4154796  2019
# 1                                        Avatar  $2,790,439,000  0417299  2005
# 2                                       Titanic  $2,195,169,696  0120338  1997
# 3    Star Wars: Episode VII - The Force Awakens  $2,068,223,624  2488496  2015
# 4                        Avengers: Infinity War  $2,048,359,754  4154756  2018
# ..                                          ...             ...      ...   ...
# 995                                 Unstoppable    $167,805,466  0477080  2010
# 996                        Three Men and a Baby    $167,780,960  0094137  1987
# 997                                  Magic Mike    $167,739,368  1915581  2012
# 998                                   Alexander    $167,298,192  0346491  2004
# 999                               Up in the Air    $166,842,739  1193138  2009
#
# [1000 rows x 4 columns]

# %%
#loop to get the plots 
import time
start_time = time.time()

plots = []
for i in range(len(movies_gross.movie_id)):
    movies_info=moviesDB.get_movie(movies_gross.movie_id[i])
    plot = movies_info['plot'][0]
    plots.append(plot)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 2729.304122686386 seconds ---

# %%
plots[4]
# Out:
# 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.::ahmetkozan'

# %%
movies_gross['plot']=plots

# %%
#new csv file with the plots
movies_gross.to_csv(path+'/'+'movies_plot.csv')

# %%
movies_gross
# Out:
#                                           title gross_worldwide movie_id  \
# 0                             Avengers: Endgame  $2,797,800,564  4154796
# 1                                        Avatar  $2,790,439,000  0417299
# 2                                       Titanic  $2,195,169,696  0120338
# 3    Star Wars: Episode VII - The Force Awakens  $2,068,223,624  2488496
# 4                        Avengers: Infinity War  $2,048,359,754  4154756
# ..                                          ...             ...      ...
# 995                                 Unstoppable    $167,805,466  0477080
# 996                        Three Men and a Baby    $167,780,960  0094137
# 997                                  Magic Mike    $167,739,368  1915581
# 998                                   Alexander    $167,298,192  0346491
# 999                               Up in the Air    $166,842,739  1193138
#
#      year                                               plot
# ...

# %%
#these next 6 cells are fixing some problems with the identification of movies
movies_gross['plot'][1]='A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.'
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
movies_gross['year'][1]=2009
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
movies_gross['movie_id'][1]= '0499549'
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
movies_gross['plot'][162]='As Earth is invaded by alien tripod fighting machines, one family fights for survival in this sci-fi action film.'
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
movies_gross['year'][162]=2005
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
movies_gross['movie_id'][162]='0407304'
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#new csv fil with the fixes
movies_gross.to_csv(path+'/'+'movies_plot2.csv')

# %%
#after  getting the infor for ids, years and shortplots and saving it in a csv, 
#we load it and keep adding interesting columns
movies_gross=pd.read_csv(r'C:\Users\Usuario\Desktop\gits\Project-Week-8-Final-Project\Data/movies_plot2.csv')

# %%
import time

# %%
#loop to get the directors, had to do it in 2 until I found how to handle the error
start_time = time.time()

directors = []
genres = []
rates = []
countries = []
for i in range(len(movies_gross.movie_id)):
    movies_info=moviesDB.get_movie(movies_gross.movie_id[i])
    director = movies_info['director']
    for j in range(len(director)):
        dire=director[j]
        dire_mov=f'{dire}-{movies_gross.movie_id[i]}'
        print(dire_mov)
        directors.append(dire_mov)
 
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Anthony Russo-4154796
# Joe Russo-4154796
# James Cameron-499549
# James Cameron-120338
# J.J. Abrams-2488496
# Anthony Russo-4154756
# Joe Russo-4154756
# Jon Favreau-6105098
# Colin Trevorrow-369610
# Joss Whedon-848228
# James Wan-2820852
# Chris Buck-4520988
# Jennifer Lee-4520988
# Joss Whedon-2395427
# David Yates-1201607
# Ryan Coogler-1825683
# Rian Johnson-2527336
# J.A. Bayona-4881806
# Chris Buck-2294629
# Jennifer Lee-2294629
# Bill Condon-2771200
# Brad Bird-3606756
# F. Gary Gray-4630562
# Shane Black-1300854
# Kyle Balda-2293640
# Pierre Coffin-2293640
# Anthony Russo-3498820
# Joe Russo-3498820
# James Wan-1477834
# Peter Jackson-167260
# Jon Watts-6320628
# Anna Boden-4154664
# Ryan Fleck-4154664
# Michael Bay-1399103
# Sam Mendes-1074638
# Michael Bay-2109248
# Christopher Nolan-1345836
# Todd Phillips-7286456
# J.J. Abrams-2527338
# Josh Cooley-1979376
# Lee Unkrich-435761
# Gore Verbinski-383574
# Gareth Edwards-3748528
# Guy Ritchie-6139732
# ...

# %%
len(directors)
# Out:
# 345

# %%
'''movies_info=moviesDB.get_movie(movies_gross.movie_id[27])
director = movies_info['director']
for j in range(len(director)):
    dire=director[j]
    dire_mov=f'{dire}-{movies_gross.movie_id[27]}'

    print(dire_mov)
    
    testing the code for the loop disregard this'''

# %%
#second part because the first one stops at 345
directors2 = []
for i in range(346,len(movies_gross.movie_id)):
    movies_info=moviesDB.get_movie(movies_gross.movie_id[i])
    try:
        director = movies_info['director']
        for j in range(len(director)):
            dire=director[j]
            dire_mov=f'{dire}-{movies_gross.movie_id[i]}'
            print(dire_mov)
            directors2.append(dire_mov)
    except KeyError:
        dire_mov=f'Not Av-{movies_gross.movie_id[i]}'
        directors2.append(dire_mov)
# Out:
# McG-438488
# Joe Johnston-458339
# Doug Liman-1631867
# Bobby Farrelly-129387
# Peter Farrelly-129387
# David Fincher-2267998
# Joe Johnston-163025
# Joel Zwick-259446
# John McTiernan-112864
# David F. Sandberg-448115
# Corin Hardy-5814060
# Tim Hill-952640
# Chris Columbus-104431
# Roger Michell-125439
# John Lasseter-120623
# Andrew Stanton-120623
# Shawn Levy-2692250
# Steven Soderbergh-349903
# Tim Burton-133152
# Todd Phillips-1951261
# Michael Apted-143145
# Raman Hui-6170484
# Rob Cohen-232500
# Darren Aronofsky-1959490
# John G. Avildsen-87538
# Genndy Tartakovsky-837562
# Steven Spielberg-181689
# Makoto Shinkai-5311514
# Tony Scott-92099
# David Yates-918940
# Sam Mendes-169547
# Hayao Miyazaki-245429
# Ron Howard-112384
# Barry Levinson-95953
# Baz Luhrmann-1343092
# Tim Burton-3861390
# Alex Proyas-343818
# Paul Verhoeven-103772
# Kenneth Branagh-3402236
# Matthew Vaughn-1270798
# Clay Kaytis-1985949
# Fergal Reilly-1985949
# Martin Campbell-113189
# ...

# %%
directors_full=directors+directors2

# %%
import pickle

# %%
#we save this list for later

with open("test.txt", "wb") as fp:   #Pickling
    pickle.dump(directors_full, fp)

# %%
#loop to get the movie genres
for i in range(len(movies_gross.movie_id)):
    movies_info=moviesDB.get_movie(movies_gross.movie_id[i])
    try:
        genre = movies_info['genres']
        for n in range(len(genre)):
            gen=genre[n]
            gen_mov=f'{gen}-{movies_gross.movie_id[i]}'
            genres.append(gen_mov)
            print(f'{i}/{len(movies_gross.movie_id)}')
                  
    except KeyError:
        gen_mov=f'Not Av-{movies_gross.movie_id[i]}'
        genres.append(gen_mov)
        print(f'{i}/{len(movies_gross.movie_id)}')
# Out:
# 0/1000
# 0/1000
# 0/1000
# 0/1000
# 1/1000
# 1/1000
# 1/1000
# 1/1000
# 2/1000
# 2/1000
# 3/1000
# 3/1000
# 3/1000
# 4/1000
# 4/1000
# 4/1000
# 5/1000
# 5/1000
# 5/1000
# 5/1000
# 5/1000
# 6/1000
# 6/1000
# 6/1000
# 7/1000
# 7/1000
# 7/1000
# 8/1000
# 8/1000
# 8/1000
# 9/1000
# 9/1000
# 9/1000
# 9/1000
# 9/1000
# 9/1000
# 10/1000
# 10/1000
# 10/1000
# 11/1000
# 11/1000
# 11/1000
# 11/1000
# 12/1000
# 12/1000
# 12/1000
# 13/1000
# 13/1000
# 13/1000
# 13/1000
# 14/1000
# 14/1000
# 14/1000
# 15/1000
# 15/1000
# 15/1000
# 15/1000
# 15/1000
# 15/1000
# 16/1000
# 16/1000
# 16/1000
# 16/1000
# 17/1000
# 17/1000
# 17/1000
# 17/1000
# 17/1000
# 17/1000
# 18/1000
# 18/1000
# 18/1000
# 18/1000
# 19/1000
# 19/1000
# 19/1000
# 20/1000
# 20/1000
# 20/1000
# 20/1000
# 20/1000
# 21/1000
# 21/1000
# 21/1000
# 22/1000
# 22/1000
# 22/1000
# 22/1000
# 23/1000
# 23/1000
# 23/1000
# 23/1000
# 24/1000
# 24/1000
# 24/1000
# 25/1000
# 25/1000
# 25/1000
# 26/1000
# 26/1000
# 26/1000
# 27/1000
# 27/1000
# ...

# %%
#we save the list for later
with open("genres.txt", "wb") as fp:   #Pickling
    pickle.dump(genres, fp)

# %%
#loop to get the rates
for i in range(len(movies_gross.movie_id)):
    movies_info=moviesDB.get_movie(movies_gross.movie_id[i])
    try:        
        rate = movies_info['rating']
        rates.append(rate)
        print(f'{i}/{len(movies_gross.movie_id)}')
    
    except KeyError:
        rate = f'Not Av-{movies_gross.movie_id[i]}'
        rates.append(rate)
        print(f'{i}/{len(movies_gross.movie_id)}')
# Out:
# 0/1000
# 1/1000
# 2/1000
# 3/1000
# 4/1000
# 5/1000
# 6/1000
# 7/1000
# 8/1000
# 9/1000
# 10/1000
# 11/1000
# 12/1000
# 13/1000
# 14/1000
# 15/1000
# 16/1000
# 17/1000
# 18/1000
# 19/1000
# 20/1000
# 21/1000
# 22/1000
# 23/1000
# 24/1000
# 25/1000
# 26/1000
# 27/1000
# 28/1000
# 29/1000
# 30/1000
# 31/1000
# 32/1000
# 33/1000
# 34/1000
# 35/1000
# 36/1000
# 37/1000
# 38/1000
# 39/1000
# 40/1000
# 41/1000
# 42/1000
# 43/1000
# 44/1000
# 45/1000
# 46/1000
# 47/1000
# 48/1000
# 49/1000
# 50/1000
# 51/1000
# 52/1000
# 53/1000
# 54/1000
# 55/1000
# 56/1000
# 57/1000
# 58/1000
# 59/1000
# 60/1000
# 61/1000
# 62/1000
# 63/1000
# 64/1000
# 65/1000
# 66/1000
# 67/1000
# 68/1000
# 69/1000
# 70/1000
# 71/1000
# 72/1000
# 73/1000
# 74/1000
# 75/1000
# 76/1000
# 77/1000
# 78/1000
# 79/1000
# 80/1000
# 81/1000
# 82/1000
# 83/1000
# 84/1000
# 85/1000
# 86/1000
# 87/1000
# 88/1000
# 89/1000
# 90/1000
# 91/1000
# 92/1000
# 93/1000
# 94/1000
# 95/1000
# 96/1000
# 97/1000
# 98/1000
# 99/1000
# ...

# %%
#we save the list for later
with open("rates.txt", "wb") as fp:   #Pickling
    pickle.dump(rates, fp)

# %%
#loop to get what country is the movie from
for i in range(len(movies_gross.movie_id)):
    movies_info=moviesDB.get_movie(movies_gross.movie_id[i])
    try:
        country = movies_info['countries']
        for m in range(len(country)):
            count=country[m]
            count_mov=f'{count}-{movies_gross.movie_id[i]}'
            country.append(count_mov)
        print(f'{i}/{len(movies_gross.movie_id)}')
        
    except KeyError:
        count_mov=f'Not Av-{movies_gross.movie_id[i]}'
        country.append(count_mov)
        print(f'{i}/{len(movies_gross.movie_id)}')
# Out:
# 0/1000
# 1/1000
# 2/1000
# 3/1000
# 4/1000
# 5/1000
# 6/1000
# 7/1000
# 8/1000
# 9/1000
# 10/1000
# 11/1000
# 12/1000
# 13/1000
# 14/1000
# 15/1000
# 16/1000
# 17/1000
# 18/1000
# 19/1000
# 20/1000
# 21/1000
# 22/1000
# 23/1000
# 24/1000
# 25/1000
# 26/1000
# 27/1000
# 28/1000
# 29/1000
# 30/1000
# 31/1000
# 32/1000
# 33/1000
# 34/1000
# 35/1000
# 36/1000
# 37/1000
# 38/1000
# 39/1000
# 40/1000
# 41/1000
# 42/1000
# 43/1000
# 44/1000
# 45/1000
# 46/1000
# 47/1000
# 48/1000
# 49/1000
# 50/1000
# 51/1000
# 52/1000
# 53/1000
# 54/1000
# 55/1000
# 56/1000
# 57/1000
# 58/1000
# 59/1000
# 60/1000
# 61/1000
# 62/1000
# 63/1000
# 64/1000
# 65/1000
# 66/1000
# 67/1000
# 68/1000
# 69/1000
# 70/1000
# 71/1000
# 72/1000
# 73/1000
# 74/1000
# 75/1000
# 76/1000
# 77/1000
# 78/1000
# 79/1000
# 80/1000
# 81/1000
# 82/1000
# 83/1000
# 84/1000
# 85/1000
# 86/1000
# 87/1000
# 88/1000
# 89/1000
# 90/1000
# 91/1000
# 92/1000
# 93/1000
# 94/1000
# 95/1000
# 96/1000
# 97/1000
# 98/1000
# 99/1000
# ...

# %%
#we save the list for later
with open("countries.txt", "wb") as fp:   #Pickling
    pickle.dump(country, fp)

# %%
#loop to get the synopsis
import time
start_time = time.time()

synopsi = []
for i in range(len(movies_gross.movie_id)):
    try:
        movies_info=moviesDB.get_movie(movies_gross.movie_id[i])
        synopsis = movies_info['synopss'][0]
    synopsi.append(synopsis)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1000 non-null   object
#  1   gross_worldwide  1000 non-null   object
#  2   movie_id         1000 non-null   object
#  3   year             1000 non-null   int64
#  4   plot             1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 86.9+ KB

# %%
#okay this might be too long and crazy
movies_info=moviesDB.get_movie(movies_gross.movie_id[3])
synopsis = movies_info['synopsis']

# %%
synopsis[0]
# Out:
# 'Luke Skywalker has vanished. In his absence, the sinister FIRST ORDER has risen from the ashes of the Empire and will not rest until Skywalker, the last Jedi, has been destroyed. With the support of the REPUBLIC, General Leia Organa leads a brave RESISTANCE. She is desperate to find her brother Luke and gain his help in restoring peace and justice to the galaxy. Leia has sent her most daring pilot on a secret mission to Jakku, where an old ally has discovered a clue to Lukes whereabouts.The First Order, led by the evil Kylo Ren, is landing stormtroopers to attack a small village, as Poe Dameron meets with Lor San Tekka in a hut. He is given a small bag containing the map to Luke Skywalker. Kylo Ren orders the stormtroopers to destroy Lor San Tekka\'s entire village and takes Poe captive. Captain Phasma, a stormtrooper wearing chrome-plated armor, leads the attack. Kylo Ren wears a black mask and uses a red, fiery lightsaber. Poe\'s X-Wing is damaged so that he cannot escape, so the 
# ...
